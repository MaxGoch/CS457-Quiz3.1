# %% [markdown]
# # Machine Learning With Python: Linear Regression With One Variable

# %% [markdown]
# # Example
# <h3 style="color:purple">Sample problem of predicting home price in monroe, new jersey (USA)</h3>

# %% [markdown]
# Below table represents current home prices in monroe township based on square feet area, new jersey
#
# We're going to use `sklearn` to build our model, you can find the library tool in here [linear model](https://scikit-learn.org/stable/modules/linear_model.html).

# %%
import glob
glob.glob('*')
# Out:
# ['003676343702302752992_0412339724.dem.bz2',
#  '1-s2.0-S2095809919306356-gr4_lrg.jpg',
#  '1-s2.0-S2095809919306356-gr5_lrg.jpg',
#  '1-s2.0-S2095809919306356-main.pdf',
#  '1249-361-001.pdf',
#  '1990-nissan-300zx-twin-turbo-imsa-gto-race-car-photo-by-bring-a-trailer_100791726_h.jpg',
#  '1993 Nissan 300zx - #1 - Made with Clipchamp.mp4',
#  '1994-nissan-300zx-105-1640195644.jpg',
#  '2010 Mitsubishi Lancer L4-2.4L  4B12 .zip',
#  '2023-2024 Application Summary _ FAFSA Application _ Federal Student Aid.pdf',
#  '20231124_105559.jpg',
#  '20231124_105922.jpg',
#  '20241216_165054.jpg',
#  '265HW7.pdf',
#  '328925__robinhood76__06101-scared-male-long-scream.wav',
#  '3440 X 1440 Wallpaper.jpg',
#  '355271-Nissan_300ZX_1991_1996 (1).zip',
#  '355271-Nissan_300ZX_1991_1996 (2).zip',
#  '355271-Nissan_300ZX_1991_1996.zip',
#  '427544488_1593920484720939_6354929949140885268_n.jpg',
#  '5e70bc8f-a7c6-4966-891d-4013f317c909.png',
#  '7th_edition_PowerPoint slides.zip',
#  'A Brief History of AI.pdf',
#  'AandB_build.sql',
#  'Algrothim_analysis_hw_10.docx',
#  'Algrothim_analysis_hw_2.docx',
#  'Algrothim_analysis_hw_3.docx',
#  'Alg_presentation_Chapter_3_2.pptx',
#  'Anaconda3-2024.10-1-Windows-x86_64.exe',
#  'Animal-Classes.zip',
#  'Annotated_Bibliography__Max Gochenour.pdf',
#  'Annual Credit Report - Experian.pdf',
#  'arduino-ide_2.1.1_Windows_64bit.exe',
#  'ArenaBreakoutInfiniteMiniloader0.0.6.235(sg).exe',
#  'Aristois-Free.jar',
#  'artworks-iYsNrpSzTaHqBuhA-E1Miyg-t500x500.jpg',
#  'assets.zip',
#  'Assignment 1 (1).docx',
#  'Assignment 1.docx',
#  'Assignment 10 Answer Sheet.sql',
#  'Assignment 10.docx',
#  'Assignment 2 (1).docx',
#  'Assignment 2 Answer Sheet LAJ 102.docx',
#  'Assignment 2 Assignment Sheet LAJ 102.pdf',
#  'Assignment 2.docx',
#  'Assignment 3 (1).docx',
#  'Assignment 3 Answer Sheet LAJ 102.docx',
#  'Assignment 3 Assignment Sheet LAJ 102.pdf',
#  'Assignment 3.docx',
#  'Assignment 4.docx',
#  'Assignment 6b.docx',
#  'Assignment 9 Answer Sheet.sql',
#  'Assignment 9.docx',
#  'Assignment_1AlgAnalysis.docx',
#  'athenaCollector v24.11 WA - Lighthouse Natural Medicine [26114].pdf',
#  'BBL Drizzy-1.21.zip',
#  'Beamngdrive20220920-04130101.mp4',
#  'bg98.jpg',
#  'bin.zip',
#  'Blank diagram.png',
#  'Blank SOA Form.docx',
#  'Book_pages_holder.stl',
#  'bRingTat.jpg',
#  'BsgLauncher.13.0.2.2031.exe',
#  'Bushing installation pdfpdf.pdf',
#  'C1R-2-2-WS.pdf',
#  'c2ez721vidv91.png',
#  'calculator.c',
#  'calculator.h',
#  'Campus_case_diagram.pdf',
#  'Central Washington University - Payment Receipt.pdf',
#  'Chap_05_Ex02.pdf',
#  'Checkout. Nike.com.pdf',
#  'Code Example Adapter Design Pattern.zip',
#  'cold, smooth & tasty..png',
#  'commitPicture.PNG',
#  'Cover-Letter.pdf',
#  'Creality_Slicer-4.8.2-build-291-win64.exe',
#  'create_my_guitar_shop.sql',
#  'creditReport_4733861422.pdf',
#  'CS312_Lab4.pdf',
#  'CS312_Research_Paper_1.pdf',
#  'CS325_Bassen_Garrett_Survey_of_Lit_RD.docx',
#  'CS361 - lab1.docx',
#  'CS380 Lab 5.png',
#  'CS380 Lab 5.zip',
#  'CS380 Proposal - Group 5.pdf',
#  'CS380FinalPres.pptx',
#  'cs427hw2 (1).docx',
#  'cs427hw2.docx',
#  'cs427hw3.docx',
#  'cs427HW5.docx',
#  'cs427HW8.docx',
#  'CS427_HW10.docx',
#  'CurseForge Windows - Installer.exe',
#  'cwu-student-schedule-of-availability-form.docx',
#  'Database Systems 7th ed..pdf',
#  'DeckOfCardsPicture.jpg',
#  'desktop.ini',
#  'disclosure.29574.en-US.pdf',
#  'dma.png',
#  'Documentation Details.pdf',
#  'e39.png',
#  'eclipse-alert-ring-of-fire-to-grace-the-skies-on-october-14-heres-everything-explained.webp',
#  'Efficient_Hardware_Architectures_for_Accelerating_Deep_Neural_Networks_Survey.pdf',
#  'Employee Paid Sick Leave Notification form.pdf',
#  'EngineTuner 1.3-2-1-3-1628261724.zip',
#  'evo.jpg',
#  'filmora-idco_setup_full1901.exe',
#  'filtered-D737C375-7417-4F05-95AE-7B35C6F8370E.mov',
#  'FinalExamPractice.pdf',
#  'firering.jpg',
#  'FitnessFiveWeb-main.zip',
#  'FitnessFive_UML.pdf',
#  'Fly Sh!t.mp4',
#  'forge-1.20.1-47.3.22-installer.jar',
#  'Fundamentals of Database Systems Seventh Edition.pdf',
#  'Fusion 360 Client Downloader.exe',
#  'Gant v Arizona 556 US 332 2009.pdf',
#  'gaypfp.jpg',
#  'gcc command.txt',
#  'gccCommand.txt',
#  'giphy_s.gif',
#  'Git-2.44.0-64-bit.exe',
#  'github-mark-c791e9551fe4',
#  'github-mark-c791e9551fe4.zip',
#  'homeprices.csv',
#  'Human-AI Collaboration in Data Science.pdf',
#  'I Want To Be Ninja! (Neenja) Original song by Jennifer Murphy.mp3',
#  'imgui-master.zip',
#  'IMG_3144.jpg',
#  'IMG_3145.jpg',
#  'IMG_3146.jpg',
#  'Intel_UPE_SpecificationsChart_2024_02_07.csv',
#  'javaDoc.png',
#  'jgrasp206_16.exe',
#  'Job Offer-Retail Sales and Store Support.pdf',
#  'JR.png',
#  'KeyCapRemover_v2_KeyCapRemover_v2_Body1_KeyCapRemover_v2.stl',
#  'kisspng-question-mark-computer-icons-exclamation-mark-desk-question-mark-emoji-5b4bb793cb77f3.3458536315316888518334.jpg',
#  'KnightsTour.c',
#  'KnightsTour.h',
#  'Lab 1.zip',
#  'Lab 6 Uml diagram.png',
#  'Lab2.txt',
#  'Lab2.zip',
#  'Lab4.c',
#  'Lab4.h',
#  'Lab4.java',
#  'Lab5.c',
#  'Lab5.h',
#  'Lab7UML.pdf',
#  'lakeWallpaper.jpg',
#  'Lecture12Quiz#1.pdf',
#  'Lecture16 Quiz 1.pdf',
#  'lghub_installer.exe',
#  'linear-regression.ipynb',
#  'LowesAgreementToArbitrateDisputes.pdf',
#  'LowesEqualEmploymentOpportunityPolicy.pdf',
#  'LowesHarassmentPolicy.pdf',
#  'LowesLockerAgreement.pdf',
#  'LowesNoticeOfPolicies.pdf',
#  'LowesPayrollDeductionAuthoriztion.pdf',
#  'LowesPaySelectionForm.pdf',
#  'LowesResourceGuide.pdf',
#  'LowesSolicitationPolicy.pdf',
#  'LowesTaxFormConsent.pdf',
#  'lowesWorkContract.pdf',
#  'low_poly_molly.stl',
#  'Manatee_v2.stl',
#  'Math330Workbook.pdf',
#  'Max Gochenour - Resume.pdf',
#  'Max Gochenour Assignment 2 Fall 2024.docx',
#  'Max Gochenour Assignment 3 Fall 2024 LAJ 102.docx',
#  'Max Gochenour Winter 2024 SOA Form.docx',
#  'Max Gochenour_academic plan 1-16-2024.docx',
#  'Max-Gochenour.pdf',
#  'Max.csv',
#  'MaxGochenour.ipynb',
#  'Max_Gochenour_Lab1.docx',
#  'Max_Gochenour_Lab1.pdf',
#  'Me and the Machines Possibilities and Pitfalls.pdf',
#  'MinHeap.java',
#  'mwFzF.png',
#  'My first project.rtf',
#  'mysql-connector-j-8.3.0',
#  'mysql-installer-community-8.0.36.0.msi',
#  'mysql-installer-web-community-8.0.36.0 (1).msi',
#  'mysql-installer-web-community-8.0.36.0.msi',
#  'nervous_dalmatian_martha_pfp_by_dionys2006_dgngbvi-fullview.jpg',
#  'New Project.png',
#  'Nissan 300ZX .glb',
#  'nissan-fairlady-300zx-z32-1989.zip',
#  'nissan300zxWallpaper.jpg',
#  'node-v22.1.0-x64.msi',
#  'OfficeSetup.exe',
#  'OpenCV-Playing-Card-Detector-master.zip',
#  'OperaGXSetup.exe',
#  'Order Status & Returns.pdf',
#  'Page_Holder_Ring_Medium.STL',
#  'Passionfruit.mp3',
#  'pcv_route_z32.jpeg',
#  'Peer evaluation form (1).docx',
#  'Peer evaluation form.docx',
#  'pfp.jpg',
#  'Phase 2 - CG5.pdf',
#  'Phone_Stand03.STL',
#  'photo-6CEADFBB-8805-4875-8670-F804B8C2F183.jpeg',
#  'pontiac.jpg',
#  'Print Receipt.pdf',
#  'python-3.11.0-amd64.exe',
#  'python-3.11.1-amd64 (1).exe',
#  'python-3.11.1-amd64.exe',
#  'python-3.13.0-amd64.exe',
#  'Receipt Z1 heatercore lines and egr delete stuff.pdf',
#  'Reddit_TikTok_Creator-main.zip',
#  'Resume_Max_Gochenour (1).docx',
#  'Resume_Max_Gochenour.docx',
#  'Resume_Max_Gochenour.pdf',
#  'retrieve.pdf',
#  'ReviewChecklist SurvRgDr Codes.docx',
#  'RobloxPlayerInstaller.exe',
#  'RockAuto Order Confirmation for Order 278875859.pdf',
#  'RockAuto Order Confirmation for Order 280968642.pdf',
#  'RUNDEN_TURBO.zip',
#  'runner.jpg',
#  'S0740624X17301946.txt',
#  's10900-022-01153-w.pdf',
#  'S2095809919306356.htm',
#  'S2095809919306356.txt',
#  'SceneBuilder-21.0.0.msi',
#  'Screenshot_20.png',
#  'Screenshot_2024-05-30_at_10.17.55_PM.jpg',
#  'Screenshot_36.png',
#  'Self Service - Applications Complete 304.pdf',
#  'Senna1.stl',
#  'set-hand-drawn-colored-morpho-menelaus-vector-28096506.jpg',
#  'Shark-Shark_v4_C.stl',
#  'signal-2024-03-13-16-08-42-091.jpg',
#  'Skyblock 4.12.3.zip',
#  'SpotifySetup.exe',
#  'Survey of Literature Rdr-Max.docx',
#  'SurveyOfLit.pdf',
#  'SV-WA-2023-2024.pdf',
#  'Syllabus_IT238_Fall_Halsey.docx',
#  'S_SSPUSADV.pdf',
#  "T-Pain - Buy U A Drank (Shawty Snappin') (Official HD Video) ft. Yung Joc.mp3",
#  'tank.jpg',
#  'tank.png',
#  'tank2.jpg',
#  'tank2.png',
#  'tattooInspo.jpg',
#  'tattooInspo2.jpg',
#  'tbk630__75427__71091.jpg',
#  'temp_image_C399AE4E-171F-480B-A9E2-530EA85BDB73.webp',
#  'Torso_Workouts_1.pdf',
#  'ttVideo - Made with Clipchamp (1).mp4',
#  'ttVideo - Made with Clipchamp (2).mp4',
#  'ttVideo - Made with Clipchamp (3).mp4',
#  'ttVideo - Made with Clipchamp (4).mp4',
#  'ttVideo - Made with Clipchamp.mp4',
#  'tw5dnc6dngg51.jpg',
#  'ubuntu-22.04.4-desktop-amd64.iso',
#  'UML_fitness.png',
#  'unnamed.jpg',
#  'UseCase.png',
#  'UseCaseDiagram.png',
#  'vacuum_diagram_z32.png',
#  'View Your Report _ TransUnion Credit Report.pdf',
#  'ViewDetails.pdf',
#  'VSCodeUserSetup-x64-1.83.0.exe',
#  'warning.png',
#  'Web Scraping or Web Crawling State of Art.pdf',
#  'Web scraping technologies in an API world (1).pdf',
#  'Web scraping technologies in an API world.pdf',
#  'Web-Crawling Reliability.pdf',
#  'Weekly Progress Report #1.pdf',
#  'Weekly Progress Report #3.pdf',
#  'WiFi-23.10.0-Driver64-Win10-Win11.exe',
#  'XaerosWorldMap_1.39.2_Forge_1.20.jar',
#  'Xaeros_Minimap_24.7.1_Forge_1.20.jar',
#  '~$sume_Max_Gochenour.docx',
#  '~WRL0003.tmp']

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
# read csv file by pandas
df = pd.read_csv('homeprices.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# Visualizing the distribution of housing prices
# we use the scatter chart in here
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',marker='+')
plt.show()

# %%
# We try to remove the price value from dataframe table and save it to area_df
area_df = df.drop('price',axis='columns')
area_df
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
#For our original file, the data has not changed. We can still call the price data through df
price = df.price
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    680000
# 4    725000
# Name: price, dtype: int64

# %% [markdown]
# ### We will use sklearn.linear_model to train a linear regression model.

# %%
# prepare the training data X = area and Y = price
X_train = area_df
y_train = price

# %%
# Create linear regression object
reg = linear_model.LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### After training, we use the trained model to make predictions
# **(1) Predict price of a home with area = 3300 sqr ft**

# %%
# The input value is area, 
# The trained model will give us the corresponding house price.

reg.predict([[3300]])
# Out:
# C:\Users\Max\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %% [markdown]
# Let's look at the parameters of linear regression
# $$y = m*x + b$$
#
# Where **m** is the coefficient and **b** is the intercept

# %%
# check the m (coefficient) or slope
reg.coef_
# Out:
# array([135.78767123])

# %%
# check the b (intercept)
reg.intercept_
# Out:
# 180616.43835616432

# %%
# Y = m * X + b (m is coefficient and b is intercept)
135.78767123 * 3300 + 180616.43835616432
# Out:
# 628715.7534151643

# %% [markdown]
# **(1) Predict price of a home with area = 5000 sqr ft**

# %%
reg.predict([[5000]])
# Out:
# C:\Users\Max\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %% [markdown]
# ### Visualize the results

# %%
# Visualizing the training set
plt.scatter(X_train, y_train, color = 'red')
# plt.scatter(X_train, regressor.predict(X_train), color = 'blue')
plt.plot(X_train, reg.predict(X_train), color = 'blue')
plt.title('<Your Name> + Area vs price')
plt.xlabel('Area')
plt.ylabel('price')
plt.grid(alpha=0.4)
plt.show()

# %% [markdown]
# # What Makes Linear Regression Understandable?
# Linear regression is easy to understand because it generates a straight line that models the relationship between variables. The method uses the cost function, specifically [mean squared error](https://en.wikipedia.org/wiki/Mean_squared_error) (MSE), to calculate the average distance of each data point from the line. By iteratively adjusting the line's slope and intercept, linear regression minimizes this distance, ensuring the line fits the data as accurately as possible.
#
# Intuitively, MSE represents an aggregation of the distances between point's actual y value and what a hypothesis function $h_\theta(x)$ predicted it would be.
#
# \begin{align}
# h_\theta(x) & = \theta_0 + \theta_1x_1 \\
# \end{align}
#
#
# That hypothesis function and the cost function $J(\theta)$ are defined as
# \begin{align}
# J(\theta) & = \frac{1}{2m}\sum\limits_{i = 1}^{m}(h_\theta(x^{(i)}) - y^{(i)})^2
# \end{align}
#
# where $\theta$ is a vector of feature weights, $x^{(i)}$ is the ith training example, $y^{(i)}$ is that example's y value, and $x_j$ is the value for its jth feature.

# %%
import numpy as np

def compute_cost(X, y, theta):
    return np.sum(np.square(np.dot(X, theta) - y)) / (2 * len(y))

# %% [markdown]
# Before computing the cost with an initial guess for $\theta$, a column of 1s is prepended onto the input data.  This allows us to vectorize the cost function, as well as make it usable for multiple linear regression later.  This first value $\theta_0$ now behaves as a constant in the cost function.

# %%
theta = np.zeros(2) # we need two parameters -  Slope and Intercept

X = np.column_stack((np.ones(len(area_df)), area_df/1000))
y = price/1000
cost = compute_cost(X, y, theta)

print('theta:', theta)
print('cost:', cost)
# Out:
# theta: [0. 0.]
# cost: 198185.0

# %%
# Example for column_stack
import numpy as np
a = np.array((1,2,3))
b = np.array((2,3,4))

np.column_stack((a,b))
# Out:
# array([[1, 2],
#        [2, 3],
#        [3, 4]])

# %% [markdown]
# We'll now minimize the cost using the [gradient descent](https://en.wikipedia.org/wiki/Gradient_descent) algorithm.  Intuitively, gradient descent takes small, linear hops down the slope of a function in each feature dimension, with the size of each hop determined by the partial derivative of the cost function with respect to that feature and a learning rate multiplier $\alpha$.  If tuned properly, the algorithm converges on a global minimum by iteratively adjusting feature weights $\theta$ of the cost function, as shown here for two feature dimensions:
#
# \begin{align}
# \theta_0 & := \theta_0 - \alpha\frac{\partial}{\partial\theta_0} J(\theta_0,\theta_1) \\
# \theta_1 & := \theta_1 - \alpha\frac{\partial}{\partial\theta_1} J(\theta_0,\theta_1)
# \end{align}
#
# The update rule each iteration then becomes:
#
# \begin{align}
# \theta_0 & := \theta_0 - \alpha\frac{1}{m} \sum_{i=1}^m (h_\theta(x^{(i)})-y^{(i)}) \\
# \theta_1 & := \theta_1 - \alpha\frac{1}{m} \sum_{i=1}^m (h_\theta(x^{(i)})-y^{(i)})x_1^{(i)} \\
# \end{align}

# %%
# Define the gradient descent function
def gradient_descent(X, y, alpha, iterations):
    """
    Performs gradient descent to minimize the cost function and find the optimal parameters.
    
    Parameters:
    X: ndarray
        Input feature matrix, where rows are samples and columns are features.
    y: ndarray
        Target values corresponding to the input data.
    alpha: float
        Learning rate to control the step size of parameter updates.
    iterations: int
        Number of iterations to run gradient descent.

    Returns:
    theta: ndarray
        Optimized parameters for the linear model.
    """
    theta = np.zeros(2)  # Initialize theta with zeros (2 parameters for simple linear regression)
    m = len(y)           # Number of training examples

    # Iterate to update theta
    for i in range(iterations):
        # Update theta[0] (intercept term) using the gradient of the cost function
        t0 = theta[0] - (alpha / m) * np.sum(np.dot(X, theta) - y)
        
        # Update theta[1] (slope term) using the gradient of the cost function
        t1 = theta[1] - (alpha / m) * np.sum((np.dot(X, theta) - y) * X[:, 1])
        
        # Update theta as a new array with the computed values
        theta = np.array([t0, t1])

    return theta

# Number of iterations for gradient descent
iterations = 5000

# Learning rate for gradient descent
alpha = 0.1

# Call the gradient descent function to compute optimized parameters
theta = gradient_descent(X, y, alpha, iterations)

# Compute the cost using the optimized parameters
cost = compute_cost(X, y, theta)

# Print the results
print("theta:", theta)  # Optimized values for theta (intercept and slope)
print('cost:', compute_cost(X, y, theta))  # Final cost value to evaluate the fit
# Out:
# theta: [180.60905845 135.78987731]
# cost: 93.40753482537946

# %%
plt.scatter(area_df, price, marker='x', color='red')
samples = np.linspace(np.min(area_df), np.max(area_df))
plt.plot(samples, theta[0]*1000 + theta[1] * samples,color = 'blue')

# plt.plot(X_train, reg.predict(X_train), color = 'Green')
plt.title('Max + Area vs price')
plt.xlabel('Area')
plt.ylabel('price')
plt.grid(alpha=0.4)
plt.show()
